# %%
from workflow_client.nb_utils.task_monitor import read_task_dataframe, plot_task_duration

task_url = "http://ibs-timf-ux1:9002/workflow_engine/data"

task_df = read_task_dataframe(task_url)

# %%
list(task_df.loc[lambda df: df.run_state == 11].id)
# Out:
# [15441,
#  19089,
#  19103,
#  19013,
#  18822,
#  19127,
#  19129,
#  19131,
#  19133,
#  19040,
#  19058,
#  19067,
#  19071,
#  19073,
#  19083]

# %%
task_df['run_state']
# Out:
# 0        15
# 1        15
# 2        15
# 3        15
# 4        15
# 5        15
# 6        15
# 7        15
# 8        15
# 9        15
# 10       15
# 11       15
# 12       15
# 13       15
# 14       15
# 15       15
# 16       10
# 17       10
# 18       15
# 19       15
# 20       10
# 21       15
# 22       15
# 23       15
# 24       15
# 25       10
# 26       10
# 27       15
# 28       15
# 29       15
#          ..
# 19066    15
# 19067    15
# 19068    15
# 19069    15
# 19070    15
# 19071    15
# 19072    15
# 19073    15
# 19074    15
# 19075    15
# 19076    15
# 19077    15
# 19078    15
# 19079    15
# 19080    15
# 19081    15
# 19082    15
# 19083    15
# 19084    15
# 19085    15
# 19086    15
# 19087    15
# 19088    15
# 19089    15
# 19090    15
# 19091    15
# 19092    11
# 19093    15
# 19094    15
# 19095    15
# Name: run_state, Length: 19096, dtype: int64

# %%
# %matplotlib inline
from workflow_client.nb_utils.task_monitor import read_task_dataframe, plot_task_duration

task_url = "http://ibs-timf-ux1:9002/workflow_engine/data"

task_df = read_task_dataframe(task_url)
plot_task_duration(task_df)

# %%
import requests, json

api_root = 'http://ibs-timf-ux1.corp.alleninstitute.org:9003/api'
url = '{}/workers?refresh=True'.format(api_root)
resp = requests.get(url)
workers = resp.json()

workers
# Out:
# {'local_at_em_imaging_workflow@at_em_imaging_workflow': {'active': [],
#   'active_queues': [{'alias': None,
#     'auto_delete': False,
#     'binding_arguments': None,
#     'bindings': [],
#     'consumer_arguments': None,
#     'durable': True,
#     'exchange': {'arguments': None,
#      'auto_delete': False,
#      'delivery_mode': None,
#      'durable': True,
#      'name': 'at_em_imaging_workflow',
#      'no_declare': False,
#      'passive': False,
#      'type': 'direct'},
#     'exclusive': False,
#     'expires': None,
#     'max_length': None,
#     'max_length_bytes': None,
#     'max_priority': None,
#     'message_ttl': None,
#     'name': 'at_em_imaging_workflow',
#     'no_ack': False,
#     'no_declare': None,
#     'queue_arguments': None,
#     'routing_key': 'at_em_imaging_workflow'}],
#   'conf': {'broker_url': 'amqp://blue_sky_user:********@ibs-timf-ux1.corp.alleninstitute.org:9008//',
# ...

# %%
[[
    i,
    k,
    ','.join(str(p) for p in v['stats']['pool']['processes'])
    ] for i, (k,v) in enumerate(workers.items())]
# Out:
# [[0, 'local_at_em_imaging_workflow@at_em_imaging_workflow', '24292,24294'],
#  [1, 'pbs_at_em_imaging_workflow@at_em_imaging_workflow', '24310,24311']]

# %%
list(workers.values())[0]
# Out:
# {'active': [],
#  'active_queues': [{'alias': None,
#    'auto_delete': False,
#    'binding_arguments': None,
#    'bindings': [],
#    'consumer_arguments': None,
#    'durable': True,
#    'exchange': {'arguments': None,
#     'auto_delete': False,
#     'delivery_mode': None,
#     'durable': True,
#     'name': 'at_em_imaging_workflow',
#     'no_declare': False,
#     'passive': False,
#     'type': 'direct'},
#    'exclusive': False,
#    'expires': None,
#    'max_length': None,
#    'max_length_bytes': None,
#    'max_priority': None,
#    'message_ttl': None,
#    'name': 'at_em_imaging_workflow',
#    'no_ack': False,
#    'no_declare': None,
#    'queue_arguments': None,
#    'routing_key': 'at_em_imaging_workflow'}],
#  'conf': {'broker_url': 'amqp://blue_sky_user:********@ibs-timf-ux1.corp.alleninstitute.org:9008//',
#   'include': ['celery.app.builtins', 'workflow_client.worker_client'],
#   'result_backend': 'rpc:///',
# ...
